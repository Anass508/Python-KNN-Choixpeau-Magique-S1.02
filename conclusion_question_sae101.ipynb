# %% [markdown]
# **Question 4 :**
#
# En effet, la fonction nb_erreurs calculant le pourcentage d'erreurs de cette méthode
# par rapport à la méthode utiliser en SAÉ S1.01, nous donne pour résultat 19. 35 %
# d’erreurs par rapport à la prédiction du choixpeau pour les élèves de première année.
# De l’autre côté, lors de la SAÉ S1.01 celui-ci s’élevait plutôt à 57 %.
# Cela nous fait une précision plus élevée et une baisse du taux d’erreurs de par la méthode de cette SAE S1.02.
# Nous pouvons conclure que la méthode implémentée dans cette SAÉ est meilleure .

# %% [markdown]
# **Question 5 :**
#
# L’application de la même méthode,
# mais en prenant comme ensemble de référence les 40 références des fondateurs plutôt que 4 références de fondateurs,
# diminue le nombre d’erreurs entre cette méthode et la prédiction du choixpeau pour les élèves de première année.
# En effet, nous passons de 19,35 % à 16,12 % ce qui est non négligeable .Elle fait donc d’elle une meilleurs approche de répartition .

# %% [markdown]
# **Question 10 :**
#
# L'utilisation de la fonction nb_erreurs,
# calculant le pourcentage d'erreurs de cette méthode avec les valeurs 1 à 5 pour k par rapport à la prédiction du choixpeau .
# Nous donne pour chaque k les valeurs suivants :
#
#
# Le pourcentage d'erreur de cette méthode avec les valeurs k=1 : 16. 12 %
# Le pourcentage d'erreur de cette méthode avec les valeurs k=2 : 16. 12 %
# Le pourcentage d'erreur de cette méthode avec les valeurs k=3 : 2. 41 %
# Le pourcentage d'erreur de cette méthode avec les valeurs k=4 : 8. 87 %
# Le pourcentage d'erreur de cette méthode avec les valeurs k=5 : 10. 48 %
#
# Nous constatons donc que la méthode définie à la question 10 est la plus performante,
# avec notamment pour k = 3 un taux d'erreurs de seulement 2,41 % par rapport à la prédiction du Choixpeau.
